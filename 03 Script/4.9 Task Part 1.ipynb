# %% [markdown]
# # Exercise 4.9 Task Part 1
# ## 1. Explore the data set
# ## 2. Wrangle data
# ## 3. Consistency checks
# ## 4. Combining data sets

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\User\241025_Instacart Basket Analysis'

# %%
customer = pd.read_csv(os.path.join(path, '02 Data','Original data', 'customers.csv'))

# %% [markdown]
# ## 1. Explore the data set

# %%
customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customer.shape
# Out:
# (206209, 10)

# %%
customer.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %% [markdown]
# ## 2. Wrangle data

# %%
# renaming columns - surname is written incorrectly 

customer.rename (columns = {'surnam' : 'surname'}, inplace = True)

# %%
customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# this did not change the column name, check column names with 

print (customer.columns)
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
# the problem was the lower case typo
customer.rename (columns = {'Surnam' : 'Surname'}, inplace = True)

# %%
customer.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# change STATE to State
customer.rename (columns = {'STATE' : 'State'}, inplace = True)

# %%
customer.head()
# Out:
#    user_id First Name   Surname  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# ## Consistency checks

# %%
customer.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# finding missing values

customer.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surname             0
# Gender              0
# State               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# see only the missing values

df_NaN = customer[customer ['First Name'].isnull() == True]

# %%
# df_NaN

# %%
# the first name is not relevant to be able to answer the key questions stated in the project brief.
# I would therefore leave the column First Name as it is and not change anything.

# %%
# finding duplicates

df_dups = customer[customer.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, State, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# there are no duplicates

# %% [markdown]
# ## 4. Combining data sets

# %%
# importing the aggregated_ords_prods_merge data set

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'aggregated_ords_prods_merge.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 25)

# %%
# droping _merge column as it is not needed any more

ords_prods_merge = ords_prods_merge.drop(columns=['_merge'])

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...    price_range_loc  \
# ...

# %%
df= ords_prods_merge[:2000000]

# %%
df.shape
# Out:
# (2000000, 24)

# %%
# combining the customer data set with the df data set which is a subset of the aggregated_ords_prods_merge data set

ords_prods_cust_merge = df.merge(customer, on = 'user_id', indicator = 'merge_status')

# %%
ords_prods_cust_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  First Name  Surname  Gender  \
# ...

# %%
ords_prods_cust_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merge.pkl'))
